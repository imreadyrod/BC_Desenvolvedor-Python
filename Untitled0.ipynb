# %%
def maior_impar(lista):
    [(n%2 != 0) for n in lista] 
    maior = n

# %%
def maior_impar(lista):
    maior = -1
        for n in lista:
          n = int(n)
            if (n%2 != 0) and (n > maior):
                 maior = n
print("O maior número ímpar da lista é: ",maior)


#     maior = n
#     if
# print(lista)
# Out:
#   File "<ipython-input-15-52d70a85bf3f>", line 4
#     for n in lista:
#     ^
# IndentationError: unexpected indent

# %%
def maior_impar(lista):
  maior = -1
for n in lista:
    n = int(n)
if (n%2 != 0) and (n > maior):
    maior = n
print("O maior número ímpar da lista é: ",maior)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-7d07dd99c9db> in <module>()
#       3 for n in lista:
#       4     n = int(n)
# ----> 5 if (n%2 != 0) and (n > maior):
#       6     maior = n
#       7 print("O maior número ímpar da lista é: ",maior)
#
# NameError: name 'maior' is not defined

# %%
def maior(lista):
  
  impar = [n for n in lista if n % 2 != 0]
  par = [x for x in lista if x % 2 == 0]
  
print('O maior número ímpar da lista é: ', max(impar))
print('O maior número par da lista é: ', max(par))

lista = [123, 234, 236, 694, 809]
maior(lista)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-0ef568142647> in <module>()
#       4   par = [x for x in lista if x % 2 == 0]
#       5
# ----> 6 print('O maior número ímpar da lista é: ', max(impar))
#       7 print('O maior número par da lista é: ', max(par))
#       8
#
# NameError: name 'impar' is not defined

# %%
lista = [123, 234, 236, 694, 809]
impar = []
par = []

for n in lista:
    if n%2==0:
        par.append(n)
    else:
        impar.append(n)

# %%
impar
# Out:
# [123, 809]

# %%
par
# Out:
# [234, 236, 694]
